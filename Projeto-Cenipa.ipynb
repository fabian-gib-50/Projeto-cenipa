# %% [markdown]
# <center><img alt="Dbian Data Scientist" width="100%" src="New_banner.png"></center>

# %% [markdown]
#    ### <strong><em> LinkdIn: By [Dbian.io Data Scientist](https://www.linkedin.com/company/81834844/admin/)<strong>

# %% [markdown]
# ## <center><strong> <em>PROJETO DE DATA SCIENTIST
#  - ESTUDOS DE CASOS COM DADOS DE ACIDENTES AÉREOS NO BRASIL<em> <strong></center>
# ___

# %% [markdown]
# <center><img alt="Dbian Data Scientist" width="95%" src="cenipa.jpg"></center>

# %% [markdown]
# ### APRESENTAÇÃO DO PROJETO `DELIMITAÇÕES` E OBJETIVOS:
#
#   - Este trabalho é delimitado inicialmente pela estrutura e dados disponíveis na base de dados pública utilizada do CENIPA e da ANAC. Desta forma, uma delimitação é o período disponível para análise de dados que corresponde aos anos de 2011 a 2020.
# Dada a sua grande abrangência, explorar todas as áreas envolvidas na análise de dados exigiria um certo tempo.
#     - Visualização das tabelas ( relacinamento entre as variaveis ), Tabelas ***fato e tabelas dimensão*** objeto de estudados desse projeto.
# ___

# %% [markdown]
# ### CONTEXTUALIZAÇÃO DOS ESTUDOS:
#
#   - Com o aumento da captação de dados e estruturas de banco de informações para tomadas de decisão, há uma grande preocupação sobre a forma de tratamento de todo esse volume de dados.
#     - Para que uma estrutura de dados possa gerar conhecimento para análise são necessárias etapas de processamento desses dados para obtenção de padrões e insights relevantes para aplicações e construção de modelos que possam predizer algo através de informações geradas a partir dos dados extraídos.
#     - A demanda por ferramentas que proporcionem a gestão de grandes volumes de DADOS, tem aumentando exponencialmente frente aos diferentes modelos de aplicações e a forma como geramos altíssimo volume de dados.
#     - No atual cenário, a estruturação, mineração e extração de informações úteis giram em torno da gestão do conhecimento, que, por sua vez, proporciona vantagem competitiva para as empresas.
#     - Pensando em modelos de aplicações que como o B.I, analisa eventos e acontecimentos já ocorridos, o trabalho de Data Science, tem como principal premissa, antever-se à fatos e suas possíveis conseguências.
#     - Toda empresa, não importa o segmento, usa informações para que possam ser mais assertivos e efetivos nas tomadas de decisão.
#     - Podemos através de informações por exemplo, evitar catástrofes, acidentes, previnir fatos e acontecimentos, mitigar aumento de custos, como também, vender mais e melhor.

# %% [markdown]
# <em><h3 style='text-align:; color:black;'> MINERAÇÃO DE DADOS </h3><em>
#
# - O pipeline de Data Scientis, têm em seu escopo, o processo de minerar dados, etapa importântíssima para todos os demais processos.
#     - Mineração de dados é a análise dos conjuntos de dados, com profundidade e com viés exploratório e observacional para encontrar relações inesperadas estruturando resumidamente os dados de forma inovadora, de fácil entendimento e útil para gerar cenarizações e criar modelos de predição.
#     - O processo de mineração de dados ganha força quando estamos frente a uma imensidão de diferentes fontes de dados com diferentes tipos e volumes. Essas estruturas de dados são como uma grande mina que, a princípio, não aparenta ter nenhum valor.
#     - A partir do momento que a exploramos aumenta a probabilidade de descobrir metais e pedras preciosas num vasto campo de sedimentos. A ciência de dados entra como um norteador, desenvolvendo inúmeras ferramentas para que a busca por conhecimento concreto se torne cada vez mais eficiente.

# %% [markdown]
# ___

# %% [markdown]
# <center><img alt="Dbian Data Scientist" width="95%" src="modelo_dados_tab_cenipa.png"></center>

# %% [markdown]
# ___
# ### <center><strong> <em>APRESENTAÇÃO DOS DETALHES DO PROJETO E SEU OBJETIVO PRINCIPAL<em> <strong></center>
#    - `ESTUDOS DE CASOS E ESTRUTURA DA ABORDAGEM`:
#
#     - Questões e/ou Hipóteses
#     - Descritiva
#     - Preditiva
#     - Prescritiva e Cenarização
# Como roteiro para a pesquisa, é desejável determinar algumas perguntas que podem nortear a análise dos dados que serão relevantes para proposição de valor sobre os resultados do projeto. Uma vez que será utilizada a base de dados de acidentes aeronáuticos no Brasil, parecem ser adequados abordar os seguintes
# questionamentos durante o processo de análise e descoberta de conhecimento:
#
#    - a) Quais são as maiores causas de ocorrências aeronáuticas no Brasil?
#    - b) Existe uma relação entre o número de acidentes e as etapas que antecedem  as operações e voos? (Pouso, decolagem, voo de cruzeiro)
#    - c) Existe alguma relação entre regiões ou estados e o número de ocorrências?
#    - d) Existe relação entre o número de ocorrências e o número de voos?
#    - e) Qual tipo de aeronave apresenta um maior número de fatos e suas causas?
#    - f) Número de ocorrências por fabricante, será que há alguma relação que evidência?
#    - g) As ocorrências com desdobramento de fatalidades têm aumentado ao longo da útima década?
# Abordagem Preditiva
# Coma o levantamento dos dadsos, mineração, tratamento e análise, podemos avaliar profundamente os dados é tentar identificar padrões que possam indicar comportamentos futuros, cujo principal objetivo é antecipar-se aos fatos e seus desdobramentos.

# %% [markdown]
#  <strong>Linguagem de programação principal <em>`PYTHON` & `Livros` de apoio aos projetos e metodologias. <em><strong></center>
#   - Linguagem de programação nativa `PYTHON` https://www.python.org/
#   - HTML
#   - IDE de desenvolvimento do projeto `Jupyter-lab`
#     - Data Scientist para Negócios
#     - Python Data Scientist Handbook
#  Obs:
#     - Para esse projeto em especial, usei formatação de fontes em HTML na IDE Jupyter Lab

# %% [markdown]
# ### Etapas dos processos

# %% [markdown]
# * <strong>Plano de Ações<strong>
#   - Seleção dos dados;<strong>
#   - Estração dos dados, muitas vezes de diferentes ambientes;
#   - Pré-processamento;
#   - Tranformação e tratamento;
#   - Data Minning;
#   - Interpretação;
#   - Apresentação (StoreTelling);

# %% [markdown]
# ### Bibliotecas e ferramentas Python aplicadas nesse prejeto

# %%
# Import das bibliotecas python

import pyforest as py
import plotly.graph_objs as go
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sb
import pandas as pd
import datetime

# %%
# Comando para consultar lista dos parâmetros "rcParams". Fontes e familias das fontes para gráficos e etc...
#plt.rcParams
#plt.rcParams.update({'axes.spines.right': False, 'axes.spines.top': False})

# plt.rcParams['figure.figsize']   = (15,7)
plt.rcParams['axes.spines.left']   = True
plt.rcParams['axes.spines.right']  = False
plt.rcParams['axes.spines.top']    = False
plt.rcParams['axes.spines.bottom'] = False

# Formatando com pd.set_option as views (visões)
pd.set_option('display.float_format','{:.2f}'.format) 
# Sem limites de linhas e colunas para as leituras
pd.set_option('display.max_columns', 50)

# Definindo a fonte padrão para os plots que serão implementados nesse projeto, bem como mapas e gráficos em geral optei por fonte "Verdana" 
mpl.rc('font', family = 'Verdana')

# Desabilitando Avisos comuns desnecessáriosplt.rcParams:
if not sys.warnoptions:
    import warnings
    warnings.simplefilter('ignore')
    warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ### Importando as tabelas para os trabalhos do <em>`CENIPA - Centro de Investigação e Prevenção de Acidentes Aeronáuticos`<em>
#   - Farei um check de todos os datates antes de submetê-los a algum tipo de tratamento, preciso me `familiarizar com os dados`.

# %%
# Importação dos dados ( são 5 tabelas ) 

# Marcando os dados nulos com os caracteres abaixo.
missing_values = ['###!','####','NULL']

ocorrencia = pd.read_csv(r'./Base/ocorrencia.csv',
                         delimiter = ';', na_values=missing_values).copy()
ocorrencia_tipo  = pd.read_csv(r'./Base/ocorrencia_tipo.csv', 
                         delimiter = ';', na_values=missing_values).copy()
aeronave = pd.read_csv(r'./Base/aeronave.csv', 
                         delimiter = ';', na_values=missing_values).copy()
fator_contribuinte = pd.read_csv(r'./Base/fator_contribuinte.csv', 
                         delimiter = ';', na_values=missing_values).copy()
recomendacao = pd.read_csv(r'./Base/recomendacao.csv', 
                         delimiter = ';', na_values=missing_values).copy()

# %% [markdown]
# ### Inciando o processo de entendimento dos dados a partir do dataset `fator_contribuinte`

# %%
# Lendo as três primeiras linhas

ocorrencia.head(n=5)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0              40211               40211               40211
# 1              40349               40349               40349
# 2              40351               40351               40351
# 3              39527               39527               39527
# 4              40324               40324               40324
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0               40211               40211                INCIDENTE
# 1               40349               40349                INCIDENTE
# 2               40351               40351                INCIDENTE
# 3               39527               39527                 ACIDENTE
# 4               40324               40324                INCIDENTE
#
#   ocorrencia_latitude ocorrencia_longitude   ocorrencia_cidade ocorrencia_uf  \
# 0                 ***                  ***      RIO DE JANEIRO            RJ
# ...

# %%
# Lendo as últimas três linhas 

ocorrencia.tail(n=5)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 6109              80245               80245               80245
# 6110              80247               80247               80247
# 6111              80251               80251               80251
# 6112              80257               80257               80257
# 6113              80259               80259               80259
#
#       codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 6109               80245               80245                INCIDENTE
# 6110               80247               80247                INCIDENTE
# 6111               80251               80251                INCIDENTE
# 6112               80257               80257                 ACIDENTE
# 6113               80259               80259                INCIDENTE
#
#      ocorrencia_latitude ocorrencia_longitude ocorrencia_cidade ocorrencia_uf  \
# ...

# %% [markdown]
# ### Criação de uma função para detalhamento sumarização dos dados com detalhes

# %%
# Função para mapear dos dados do dataset 

def summary_missing_values(df):
    missing_values = pd.DataFrame(ocorrencia.isna().sum()/ocorrencia.shape[0])
    missing_values.reset_index(drop=True, inplace=True)    
    missing_values.columns = ["Absoluto dados ausentes(%)"]
    missing_values["Column"] = pd.Series(ocorrencia.columns).values
    # Make index be the column "Absolute Missing (%)"
    missing_values.reset_index(drop=True, inplace=True)
    missing_values.set_index("Column", inplace=True)
    
    # Calculando os valores comparando com o tatal de dados por coluna e os dados ausentes quantitativos em percentual
    column_missing = []
    column_total   = []
    column_miss    = []
    column_type    = []
    for column in ocorrencia.columns:
        col_miss = ocorrencia[column].isnull().sum()
        total_values = ocorrencia[column].count()       
        column_miss.append(col_miss)
        column_total.append(total_values) 
        column_missing.append((col_miss/total_values))
        column_type.append(column_type)
        
    # Construindo o dataframe que receberá os valores
    missing_values["Perc. Abs. ausentes(%)"] = pd.Series(column_missing).values
    missing_values["Perc. da equivalência(%)"] = -(pd.Series(column_missing).values-1)
    missing_values["Valores únicos"] = pd.Series(column_total).values
    missing_values["Valores absolutos"] = pd.Series(column_miss).values
    missing_values['Variáveis tipos'] = pd.DataFrame(ocorrencia.dtypes, columns=['column_type'])
    missing_values.sort_values(by="Absoluto dados ausentes(%)", ascending=False, inplace=True)
    missing_columns = list(missing_values.query("`Absoluto dados ausentes(%)` > 0").index)
    
    pd.options.display.float_format = '{:.2%}'.format
    return missing_values, missing_columns

missing_values, missing_columns_names = summary_missing_values(ocorrencia)
missing_values
# Out:
#                                 Absoluto dados ausentes(%)  \
# Column
# divulgacao_dia_publicacao                           74.21%
# ocorrencia_latitude                                 25.55%
# ocorrencia_longitude                                25.55%
# divulgacao_relatorio_numero                         13.00%
# investigacao_status                                  5.58%
# investigacao_aeronave_liberada                       4.69%
# ocorrencia_aerodromo                                 0.31%
# ocorrencia_hora                                      0.02%
# ocorrencia_dia                                       0.00%
# total_aeronaves_envolvidas                           0.00%
# total_recomendacoes                                  0.00%
# divulgacao_relatorio_publicado                       0.00%
# codigo_ocorrencia                                    0.00%
# codigo_ocorrencia1                                   0.00%
# ocorrencia_pais                                      0.00%
# ...

# %%
# Função responsável pelo preenchimento do valores nulos de uma lista de atributos, entrada: Dataframe, Lista de atributos afetados e valor a ser preenchido

def preencher_nulos(dataframe, lista_colunas, valor ):
    for coluna in lista_colunas:
     dataframe[coluna].fillna(0, inplace=True)
    
preencher_nulos(ocorrencia,['ocorrencia_uf','ocorrencia_latitude','ocorrencia_longitude'],'NI')

# %%
aeronave.head(n=3)
# Out:
#    codigo_ocorrencia2 aeronave_matricula aeronave_operador_categoria  \
# 0               39115              PTNQX                         ***
# 1               39155              PTLVI                         ***
# 2               39156              PPPTO                         ***
#
#   aeronave_tipo_veiculo          aeronave_fabricante aeronave_modelo  \
# 0                 AVIÃO  NEIVA INDUSTRIA AERONAUTICA        EMB-711A
# 1                 AVIÃO               BEECH AIRCRAFT             C90
# 2                 AVIÃO      AEROSPATIALE AND ALENIA     ATR-72-212A
#
#   aeronave_tipo_icao aeronave_motor_tipo aeronave_motor_quantidade  \
# 0               P28R              PISTÃO                 MONOMOTOR
# 1               BE9L          TURBOÉLICE                   BIMOTOR
# 2               AT72          TURBOÉLICE                   BIMOTOR
#
#    aeronave_pmd  aeronave_pmd_categoria  aeronave_assentos  \
# 0          1202                    1202            400.00%
# ...

# %%
fator_contribuinte.head(n=3)
# Out:
#    codigo_ocorrencia3               fator_nome             fator_aspecto  \
# 0               39115    APLICAÇÃO DE COMANDOS  DESEMPENHO DO SER HUMANO
# 1               39115  JULGAMENTO DE PILOTAGEM  DESEMPENHO DO SER HUMANO
# 2               39115                PERCEPÇÃO       ASPECTO PSICOLÓGICO
#
#     fator_condicionante         fator_area
# 0  OPERAÇÃO DA AERONAVE  FATOR OPERACIONAL
# 1  OPERAÇÃO DA AERONAVE  FATOR OPERACIONAL
# 2            INDIVIDUAL       FATOR HUMANO

# %%
recomendacao.head(3)
# Out:
#    codigo_ocorrencia4 recomendacao_numero recomendacao_dia_assinatura  \
# 0               39115            095/2011                  2011-07-21
# 1               39115            096/2011                  2011-07-21
# 2               39156            063/2011                  2011-06-30
#
#   recomendacao_dia_encaminhamento recomendacao_dia_feedback  \
# 0                      2011-08-01                2015-12-21
# 1                      2011-08-01                2011-09-16
# 2                      2011-08-01                2011-09-12
#
#                                recomendacao_conteudo recomendacao_status  \
# 0  Revisar os requisitos de experiência recente p...        NÃO CUMPRIDA
# 1  Divulgar o presente relatório final aos operad...            CUMPRIDA
# 2  Divulgar este Relatório aos operadores de aero...            CUMPRIDA
#
#   recomendacao_destinatario_sigla          recomendacao_destinatario
# 0                            ANAC  AGÊNCIA NACIONAL DE AVIAÇÃO CIVIL
# ...

# %%
# Verificando se os códigos de ocorrência foram replicados 

valores_totalmente_replicados = len(ocorrencia.query('codigo_ocorrencia == codigo_ocorrencia1 &'+
                                                     'codigo_ocorrencia == codigo_ocorrencia2 &'+
                                                     'codigo_ocorrencia == codigo_ocorrencia3 &'+
                                                     'codigo_ocorrencia == codigo_ocorrencia4'))

print('')
print(f'Resultado da análise preliminar')
print(f'Total de ocorrências no dataset:\t\t{ocorrencia.shape[0]} \n' +
      f'Total de ocorrências com valores replicados:\t{valores_totalmente_replicados}')
# Out:
# Resultado da análise preliminar
# Total de ocorrências no dataset:		6114
# Total de ocorrências com valores replicados:	6114

# %%
ocorrencia['ocorrencia_pais'].value_counts()
# Out:
# BRASIL    6114
# Name: ocorrencia_pais, dtype: int64

# %%
ocorrencia['ocorrencia_hora'].value_counts()
# Out:
# 20:00:00    134
# 13:00:00    101
# 19:00:00     99
# 13:30:00     97
# 18:30:00     90
#            ...
# 23:54:00      1
# 12:09:00      1
# 01:54:00      1
# 18:41:00      1
# 17:21:00      1
# Name: ocorrencia_hora, Length: 982, dtype: int64

# %%
# Checagem data início e fim

print('Período dos dados análisados')
print(f'Data inícial:\t',ocorrencia.ocorrencia_dia.min())
print(f'Data final:\t',ocorrencia.ocorrencia_dia.max())
# Out:
# Período dos dados análisados
# Data inícial:	 01/01/2011
# Data final:	 31/12/2020

# %%
# Remoção de colunas que nesse momento e posteriormente não serão usadas nessa tabela

ocorrencia = ocorrencia.drop(columns=['codigo_ocorrencia1',
                                      'codigo_ocorrencia2',
                                      'codigo_ocorrencia3',
                                      'codigo_ocorrencia4',
                                      # 'ocorrencia_latitude',
                                      # 'ocorrencia_longitude',
                                      # 'ocorrencia_cidade',
                                      # 'ocorrencia_pais',
                                      'ocorrencia_aerodromo',
                                      'investigacao_aeronave_liberada',
                                      'investigacao_status',
                                      'divulgacao_relatorio_numero',
                                      'divulgacao_relatorio_publicado',
                                      'divulgacao_dia_publicacao',
                                      'total_recomendacoes',
                                       ]).copy()

# %%
# Renomeando a coluna total_aeronaves_envolvidas para "ocorrencia_aeronaves_envtabela paras"

ocorrencia = ocorrencia.rename(columns={'total_aeronaves_envolvidas':
                                        'oc_aeronaves_envolvidas',
                                        'ocorrencia_latitude': 'latitude',
                                        'ocorrencia_longitude': 'longitude',
                                        'ocorrencia_uf':'uf'},).copy()

# Abrindo a base para ver como ficou após os tratamentos implementados 
# Checando as entradas depois do tratamento e otimização dos dados.

print( 'Dimensões do Dataset colunas:\t {}'.format(ocorrencia.shape[1]) )
print( 'Dimensões do Dataset entradas:\t {}'.format(ocorrencia.shape[0]) )
ocorrencia.head()
# Out:
# Dimensões do Dataset colunas:	 11
# Dimensões do Dataset entradas:	 6114
#    codigo_ocorrencia ocorrencia_classificacao        latitude       longitude  \
# 0              40211                INCIDENTE             ***             ***
# 1              40349                INCIDENTE               0               0
# 2              40351                INCIDENTE               0               0
# 3              39527                 ACIDENTE  -13.1066666667  -55.9930555556
# 4              40324                INCIDENTE               0               0
#
#     ocorrencia_cidade  uf ocorrencia_pais ocorrencia_dia ocorrencia_hora  \
# 0      RIO DE JANEIRO  RJ          BRASIL     03/01/2010        12:00:00
# 1               BELÉM  PA          BRASIL     03/01/2010        11:05:00
# 2      RIO DE JANEIRO  RJ          BRASIL     03/01/2010        03:00:00
# 3  LUCAS DO RIO VERDE  MT          BRASIL     04/01/2010        17:30:00
# ...

# %% [markdown]
# ### Criação de funções auxiliares
#   - Farei alguns teste quanto a eficiência da função para os trabalhos, se fizer sentido uso, do contrário, será inativada.

# %%
# Funcão para preencher com mediana de latitude e longitude para os dados faltantes das variáveis em questão, para plotagem de mapa com ocorrencias.

# def mediana_lat_por_cidade(cidade, lat_long, column):
#     value = lat_long[lat_long['ocorrencia_cidade'] == cidade][column]\
#     .apply(pd.to_numeric, args=['coerce']).dropna().median()
#     return value

# %%
# Função para verificar e guardar lat e long caso os valores sejam válidos para sua otimização. 

# def contain_number(series):
#     index_list = []
#     series = list(zip(series.index, series.values))
#     for index, value in series:
#         try:
#             value = str(value)
#             if any(st.isdigit() for st in value):
#                 index_list.append(index)
#         except:
#              continue
#     return index_list

# %%
# Tratamentos necessários para otimizar o dataset

# oc_cenipa_trat = ocorrencia[[ 'codigo_ocorrencia',
#                               'uf',
#                               'ocorrencia_cidade',
#                               'latitude',
#                               'longitude',
#                               # 'ocorrencia_dia',
#                               'ocorrencia_classificacao' 
#                             ]].drop_duplicates()

# lat_long_null = oc_cenipa_trat.loc[oc_cenipa_trat.index.isin(contain_number(oc_cenipa_trat['latitude']))]
# # lat_long_null = oc_cenipa_trat.loc[~oc_cenipa_trat.index.isin(contain_number(oc_cenipa_trat['latitude']))]

# lat_long_not_null = oc_cenipa_trat.loc[oc_cenipa_trat.index.isin(contain_number(oc_cenipa_trat['latitude']))]

# lat_long_null['latitude'] = lat_long_null.apply(lambda row: mediana_lat_por_cidade(row['ocorrencia_cidade'], 
#                                                                       oc_cenipa_trat, 'latitude'), axis=1)
# lat_long_null['longitude'] = lat_long_null.apply(lambda row: mediana_lat_por_cidade(row['ocorrencia_cidade'], 
#                                                                       oc_cenipa_trat, 'longitude'), axis=1)

# oc_cenipa_trat_ot = pd.concat([ lat_long_not_null, lat_long_null ])

# oc_cenipa_trat_ot.head(5) #= oc_cenipa_trat_ot.rename({'ocorrencia_uf':'uf'}, axis = 1).copy()

# %%
# Checagem das otimizações e tratamentos 

# oc_cenipa_trat_ot.head(3)

# %%
# Método numpy para compreender os quantitativos por ocorrência

np.unique(ocorrencia['ocorrencia_classificacao'], return_counts=True)
# Out:
# (array(['ACIDENTE', 'INCIDENTE', 'INCIDENTE GRAVE'], dtype=object),
#  array([1930, 3393,  791], dtype=int64))

# %%
# Criando o atributo ocorrencia_ano a partir do atributo ocorrencia_dia 

ocorrencia['ocorrencia_ano'] = ocorrencia['ocorrencia_dia'].apply(lambda x : x.replace(x,x[-4:]))

# Convertendo o tipo do atributo ocorrencia_ano para inteiro 

ocorrencia = ocorrencia.astype({'ocorrencia_ano': 'int64',
                                'oc_aeronaves_envolvidas':'int64'})

# Extraíndo entradas da variável (latitude', 'longitude) para enriquecer as análises com essa variável 

# ocorrencia = ocorrencia.dropna(subset=['latitude', 'longitude'], axis=0) # Eixo = 0 linhas / Eixo = 1 Colmns

# Removendo o atributo ocorrencia_dia 

ocorrencia = ocorrencia.drop(columns=['ocorrencia_dia'],)
ocorrencia.head(3)
# Out:
#    codigo_ocorrencia ocorrencia_classificacao latitude longitude  \
# 0              40211                INCIDENTE      ***       ***
# 1              40349                INCIDENTE        0         0
# 2              40351                INCIDENTE        0         0
#
#   ocorrencia_cidade  uf ocorrencia_pais ocorrencia_hora  \
# 0    RIO DE JANEIRO  RJ          BRASIL        12:00:00
# 1             BELÉM  PA          BRASIL        11:05:00
# 2    RIO DE JANEIRO  RJ          BRASIL        03:00:00
#
#    oc_aeronaves_envolvidas ocorrencia_saida_pista  ocorrencia_ano
# 0                        1                    NÃO            2010
# 1                        1                    NÃO            2010
# 2                        1                    NÃO            2010

# %%
# Criando uma função para tratamento dos atributos "datetime" por faixa de horário das ocorrências
# Estruturando os binários de hora, minutos e segundos para criar um novo formato datetime
'''
  Função recebe a pd.Series com strings referentes a horários  e retorna 
  uma lista de períodos com os valores MANHÃ, TARDE, NOITE ou MADRUGADA
'''
def faixa_periodo_dia(series):
    periodos = []

    for valor in series:
      if not isinstance(valor, str):
         valor = '00:00:00'

      hora_valor     = int(valor[:2])
      minutos_valor  = int(valor[3:5])
      segundos_valor = int(valor[6:])
      hora = datetime.time(hora_valor,minutos_valor,segundos_valor)
    
      if datetime.time(0,0,0)    <= hora < datetime.time(5,59,59):
        periodos.append('MADRUGADA')
      elif datetime.time(6,0,0)  <= hora < datetime.time(11,59,59):
        periodos.append('MANHA')
      elif datetime.time(12,0,0) <= hora < datetime.time(17,59,59):
        periodos.append('TARDE')
      elif datetime.time(18,0,0) <= hora < datetime.time(23,59,59):
        periodos.append('NOITE')

    return periodos

# %%
# Recebe a lista de períodos identificados a partir da lista de ocorencias 

lista_periodos = faixa_periodo_dia(ocorrencia['ocorrencia_hora'])

# Adiciona o atributo ocorrencia_periodo
ocorrencia['ocorrencia_periodos'] = pd.Series(lista_periodos)

# Removendo o atributo ocorrencia_hora
ocorrencia.drop(columns=['ocorrencia_hora'], inplace = True)

# %%
ocorrencia.head()
# Out:
#    codigo_ocorrencia ocorrencia_classificacao        latitude       longitude  \
# 0              40211                INCIDENTE             ***             ***
# 1              40349                INCIDENTE               0               0
# 2              40351                INCIDENTE               0               0
# 3              39527                 ACIDENTE  -13.1066666667  -55.9930555556
# 4              40324                INCIDENTE               0               0
#
#     ocorrencia_cidade  uf ocorrencia_pais  oc_aeronaves_envolvidas  \
# 0      RIO DE JANEIRO  RJ          BRASIL                        1
# 1               BELÉM  PA          BRASIL                        1
# 2      RIO DE JANEIRO  RJ          BRASIL                        1
# 3  LUCAS DO RIO VERDE  MT          BRASIL                        1
# 4             PELOTAS  RS          BRASIL                        1
#
#   ocorrencia_saida_pista  ocorrencia_ano ocorrencia_periodos
# ...

# %% [markdown]
# ### Tratamentos para o dataset `ocorrências_tipo`

# %%
ocorrencia_tipo.head()
# Out:
#    codigo_ocorrencia1                                    ocorrencia_tipo  \
# 0               39115                                          PANE SECA
# 1               39155                           VAZAMENTO DE COMBUSTÍVEL
# 2               39156                                        FOGO EM VOO
# 3               39158                                   SUPERAQUECIMENTO
# 4               39176  FALHA OU MAU FUNCIONAMENTO DE SISTEMA / COMPON...
#
#                            ocorrencia_tipo_categoria taxonomia_tipo_icao
# 0                            COMBUSTÍVEL | PANE SECA                FUEL
# 1  FALHA OU MAU FUNCIONAMENTO DE SISTEMA / COMPON...              SCF-NP
# 2            FOGO/FUMAÇA (SEM IMPACTO) | FOGO EM VOO                F-NI
# 3  FALHA OU MAU FUNCIONAMENTO DO MOTOR | SUPERAQU...              SCF-PP
# 4  FALHA OU MAU FUNCIONAMENTO DE SISTEMA / COMPON...              SCF-NP

# %%
display(ocorrencia_tipo.dtypes)
# Out:
# codigo_ocorrencia1            int64
# ocorrencia_tipo              object
# ocorrencia_tipo_categoria    object
# taxonomia_tipo_icao          object
# dtype: object

# %% [markdown]
# ### Array para enxergar melhor os valores unicos da variável "ocorrencia_tipo"

# %%
# Método numpy para compreender os quantitativos por ocorrência tipo categoria

np.unique(ocorrencia_tipo['ocorrencia_tipo_categoria'], return_counts=False)
# Out:
# array(['*** COLISÃO EM VOO COM OBSTÁCULO (excluir)',
#        '*** SAÍDA DE PISTA - (excluir)', 'AERÓDROMO', 'COLISÃO COM AVE',
#        'COLISÃO COM FAUNA',
#        'COLISÃO COM OBSTÁCULO DURANTE A DECOLAGEM E POUSO',
#        'COLISÃO NO SOLO',
#        'COLISÃO NO SOLO | COLISÃO COM AERONAVE NO SOLO',
#        'COLISÃO NO SOLO | COLISÃO COM OBSTÁCULOS NO SOLO',
#        'COM CARGAS EXTERNAS', 'COMBUSTÍVEL', 'COMBUSTÍVEL | PANE SECA',
#        'CONTATO ANORMAL COM A PISTA |',
#        'CONTATO ANORMAL COM A PISTA | POUSO BRUSCO',
#        'CONTATO ANORMAL COM A PISTA | POUSO SEM TREM',
#        'CORTANTE DE VENTO / TEMPESTADE', 'EXCURSÃO DE PISTA',
#        'EXCURSÃO DE PISTA | POUSO LONGO',
#        'FALHA OU MAU FUNCIONAMENTO DE SISTEMA / COMPONENTE',
#        'FALHA OU MAU FUNCIONAMENTO DE SISTEMA / COMPONENTE | ALARME FALSO DE FOGO OU DE SUPERAQUECIMENTO',
#        'FALHA OU MAU FUNCIONAMENTO DE SISTEMA / COMPONENTE | COM COMANDOS DE VOO',
# ...

# %%
# Renomeando a coluna codigo_ocorrencia1 para codigo_ocorrencia 

ocorrencia_tipo.rename(columns={'codigo_ocorrencia1':'codigo_ocorrencia'}, inplace=True )

# %%
# Marca e retorna todas as duplicatas
todas_duplicatas = ocorrencia_tipo['codigo_ocorrencia'].duplicated(keep=False).sum()

# Marca todas as duplicatas com exceção da primeira ocorrência
duplicatas_sem_primeira_ocorrencia = ocorrencia_tipo['codigo_ocorrencia'].duplicated(keep='first').sum()

print('')
print(f'Resultado da análise preliminar')
print(f'Total de ocorrências no dataset:\t\t\t{todas_duplicatas} \n' +
      f'Total de ocorrências com valores totalmente replicados: {duplicatas_sem_primeira_ocorrencia}')
# Out:
# Resultado da análise preliminar
# Total de ocorrências no dataset:			331
# Total de ocorrências com valores totalmente replicados: 169

# %%
# Filtro marcando as duplicatas como True, com exceção da primeira ocorrência 
filtro_duplicatas = ocorrencia_tipo['codigo_ocorrencia'].duplicated(keep='first')

# Obter o índice das duplicatas
indices = ocorrencia_tipo[filtro_duplicatas].index

# Remover os registros das duplicatas usando o índice como referência
ocorrencia_tipo.drop(indices, inplace=True)

# Criando um novo Dataframe apenas com as atributos codigo_ocorrencia e 
# ocorrencia_tipo
tipo_ocorrencia = ocorrencia_tipo[['codigo_ocorrencia','ocorrencia_tipo']]

ocorrencia_com_tipo_associado = len(tipo_ocorrencia['codigo_ocorrencia'].unique())

print('')
print(f"Número de ocorrências por tipo correlacionado:" +
                f" {ocorrencia_com_tipo_associado}")
# Out:
# Número de ocorrências por tipo correlacionado: 6114

# %% [markdown]
# ### Farei uma união com join pelo código das ocorrências

# %%
# Realizando o join para juntar o Dataframe tipo_ocorrencia ao Dataframe ocorrencia
# utilizando o codigo_ocorrencia como chave 

ocorrencia = ocorrencia.join(tipo_ocorrencia.set_index('codigo_ocorrencia'), on='codigo_ocorrencia')

# %%
ocorrencia.head()
# Out:
#    codigo_ocorrencia ocorrencia_classificacao        latitude       longitude  \
# 0              40211                INCIDENTE             ***             ***
# 1              40349                INCIDENTE               0               0
# 2              40351                INCIDENTE               0               0
# 3              39527                 ACIDENTE  -13.1066666667  -55.9930555556
# 4              40324                INCIDENTE               0               0
#
#     ocorrencia_cidade  uf ocorrencia_pais  oc_aeronaves_envolvidas  \
# 0      RIO DE JANEIRO  RJ          BRASIL                        1
# 1               BELÉM  PA          BRASIL                        1
# 2      RIO DE JANEIRO  RJ          BRASIL                        1
# 3  LUCAS DO RIO VERDE  MT          BRASIL                        1
# 4             PELOTAS  RS          BRASIL                        1
#
#   ocorrencia_saida_pista  ocorrencia_ano ocorrencia_periodos  \
# ...

# %% [markdown]
# ### Tratamentos para o dataset `Aeronave`

# %%
display(aeronave.dtypes)
# Out:
# codigo_ocorrencia2               int64
# aeronave_matricula              object
# aeronave_operador_categoria     object
# aeronave_tipo_veiculo           object
# aeronave_fabricante             object
# aeronave_modelo                 object
# aeronave_tipo_icao              object
# aeronave_motor_tipo             object
# aeronave_motor_quantidade       object
# aeronave_pmd                     int64
# aeronave_pmd_categoria           int64
# aeronave_assentos              float64
# aeronave_ano_fabricacao        float64
# aeronave_pais_fabricante        object
# aeronave_pais_registro          object
# aeronave_registro_categoria     object
# aeronave_registro_segmento      object
# aeronave_voo_origem             object
# aeronave_voo_destino            object
# aeronave_fase_operacao          object
# aeronave_tipo_operacao          object
# aeronave_nivel_dano             object
# aeronave_fatalidades_total       int64
# dtype: object

# %%
aeronave.describe().drop(['count'])
# Out:
#       codigo_ocorrencia2  aeronave_pmd  aeronave_pmd_categoria  \
# mean         5982219.33%   1544845.17%             1544845.17%
# std          1454709.73%   3540418.06%             3540418.06%
# min          3911500.00%         0.00%                   0.00%
# 25%          4659775.00%    115700.00%              115700.00%
# 50%          5311550.00%    207300.00%              207300.00%
# 75%          7814450.00%    603300.00%              603300.00%
# max          8025900.00%  39689500.00%            39689500.00%
#
#       aeronave_assentos  aeronave_ano_fabricacao  aeronave_fatalidades_total
# mean           2858.20%               189122.71%                      14.74%
# std            5565.42%                45419.77%                      67.46%
# min               0.00%                    0.00%                       0.00%
# 25%             200.00%               197800.00%                       0.00%
# 50%             600.00%               199200.00%                       0.00%
# ...

# %%
# Renomeando a coluna 

aeronave.rename(columns={'codigo_ocorrencia2':'codigo_ocorrencia'},
                                                      inplace=True)

# %%
# Remoção de colunas irrelevantes para o projeto 

aeronave = aeronave.drop(columns=['aeronave_matricula',
                                  'aeronave_operador_categoria',
                                  'aeronave_tipo_icao',
                                  'aeronave_pmd_categoria',
                                  'aeronave_assentos',
                                  'aeronave_ano_fabricacao',
                                  'aeronave_modelo',
                                  'aeronave_pais_fabricante',
                                  'aeronave_pais_registro',
                                  'aeronave_registro_categoria',
                                  'aeronave_voo_origem',
                                  'aeronave_voo_destino',
                                  'aeronave_tipo_operacao'],)

# %%
# Preenchendo os atributos numéricos com o valor 0 

preencher_nulos(aeronave,['aeronave_pmd','aeronave_fatalidades_total'],0)

# Preenchendo os categóricos categóricos com 'NÃO INFORMADO'
preencher_nulos(aeronave,['aeronave_tipo_veiculo', 
                          'aeronave_fabricante',
                          'aeronave_motor_tipo',
                          'aeronave_motor_quantidade',
                          'aeronave_registro_segmento',
                          'aeronave_fase_operacao',
                          'aeronave_nivel_dano'],'NI')

# %%
# Convertendo os atributos float para int

aeronave = aeronave.astype({'aeronave_fatalidades_total': 'int64'})

# %%
aeronave.head(n=5)
# Out:
#    codigo_ocorrencia aeronave_tipo_veiculo          aeronave_fabricante  \
# 0              39115                 AVIÃO  NEIVA INDUSTRIA AERONAUTICA
# 1              39155                 AVIÃO               BEECH AIRCRAFT
# 2              39156                 AVIÃO      AEROSPATIALE AND ALENIA
# 3              39158                 AVIÃO               BOEING COMPANY
# 4              39176                 AVIÃO             AIRBUS INDUSTRIE
#
#   aeronave_motor_tipo aeronave_motor_quantidade  aeronave_pmd  \
# 0              PISTÃO                 MONOMOTOR          1202
# 1          TURBOÉLICE                   BIMOTOR          4377
# 2          TURBOÉLICE                   BIMOTOR         22500
# 3                JATO                   BIMOTOR        108862
# 4                JATO                   BIMOTOR         77000
#
#   aeronave_registro_segmento aeronave_fase_operacao aeronave_nivel_dano  \
# 0                 PARTICULAR              DECOLAGEM         SUBSTANCIAL
# ...

# %% [markdown]
# ### Criação de uma variável para filtro do peso das aeronaves com base nas informações existentes.

# %%
# Criando filtro faixa para análises posteriores ( novos atributos ) 

pesos_maximos = []

for i in aeronave['aeronave_pmd']:
  if i == 0:
    pesos_maximos.append('NI')
  elif i <= 2250.0:
    pesos_maximos.append('Faixa ate 2250KG')
  elif i <= 5700.0:
    pesos_maximos.append('Faixa de 2250KG e 5700KG')
  elif i > 5700.0:
    pesos_maximos.append('Acima de 5700KG')

aeronave['aeronave_peso_maximo_decolagem'] = pd.Series(pesos_maximos)

aeronave = aeronave.drop(columns=['aeronave_pmd'],)

# %%
df_aeronave_ocorrencias = aeronave.\
  join(ocorrencia.set_index('codigo_ocorrencia'),\
  on='codigo_ocorrencia')

# %%
df_aeronave_ocorrencias.head()
# Out:
#    codigo_ocorrencia aeronave_tipo_veiculo          aeronave_fabricante  \
# 0              39115                 AVIÃO  NEIVA INDUSTRIA AERONAUTICA
# 1              39155                 AVIÃO               BEECH AIRCRAFT
# 2              39156                 AVIÃO      AEROSPATIALE AND ALENIA
# 3              39158                 AVIÃO               BOEING COMPANY
# 4              39176                 AVIÃO             AIRBUS INDUSTRIE
#
#   aeronave_motor_tipo aeronave_motor_quantidade aeronave_registro_segmento  \
# 0              PISTÃO                 MONOMOTOR                 PARTICULAR
# 1          TURBOÉLICE                   BIMOTOR                 PARTICULAR
# 2          TURBOÉLICE                   BIMOTOR                    REGULAR
# 3                JATO                   BIMOTOR                    REGULAR
# 4                JATO                   BIMOTOR                    REGULAR
#
#   aeronave_fase_operacao aeronave_nivel_dano  aeronave_fatalidades_total  \
# ...

# %%
display(df_aeronave_ocorrencias.dtypes)
# Out:
# codigo_ocorrencia                  int64
# aeronave_tipo_veiculo             object
# aeronave_fabricante               object
# aeronave_motor_tipo               object
# aeronave_motor_quantidade         object
# aeronave_registro_segmento        object
# aeronave_fase_operacao            object
# aeronave_nivel_dano               object
# aeronave_fatalidades_total         int64
# aeronave_peso_maximo_decolagem    object
# ocorrencia_classificacao          object
# latitude                          object
# longitude                         object
# ocorrencia_cidade                 object
# uf                                object
# ocorrencia_pais                   object
# oc_aeronaves_envolvidas            int64
# ocorrencia_saida_pista            object
# ocorrencia_ano                     int64
# ocorrencia_periodos               object
# ocorrencia_tipo                   object
# dtype: object

# %% [markdown]
# ### Finalizando os trabalhos e salvando o dataset para novos procedimentos

# %%
# Salvando os trabalhos em um novo dataframe

df_aeronave_ocorrencias.to_csv(r'./aeronave_ocorrencias_tratado.csv',\
                                                  sep=';', index=False)

# %% [markdown]
# ### Passando o dataset para outro objeto python
#   - Processo de entendimento dos próximos passos, com aplicação de análises`EDA`
#    - Análise dos dados e estatística aplicada aos processos que serão desencadeados com base nos entendimentos anteriores.
# - Abrindo a base salva para o EDA
#    - Criando o `file_path` e guardando dentro de outro objeto python == data

# %%
# Chamada do file_path

file_path = (r'./aeronave_ocorrencias_tratado.csv')
data      = pd.read_csv(file_path, 
                        delimiter=';').copy()

# Imprimindo na tela a sumarização de pois do dataset tratado e otimizado para às análises.

print('Sumarizacao colunas:\t', data.shape[1])
print('Sumarizacao registros:\t', data.shape[0])
data.head(n=5)
# Out:
# Sumarizacao colunas:	 21
# Sumarizacao registros:	 6188
#    codigo_ocorrencia aeronave_tipo_veiculo          aeronave_fabricante  \
# 0              39115                 AVIÃO  NEIVA INDUSTRIA AERONAUTICA
# 1              39155                 AVIÃO               BEECH AIRCRAFT
# 2              39156                 AVIÃO      AEROSPATIALE AND ALENIA
# 3              39158                 AVIÃO               BOEING COMPANY
# 4              39176                 AVIÃO             AIRBUS INDUSTRIE
#
#   aeronave_motor_tipo aeronave_motor_quantidade aeronave_registro_segmento  \
# 0              PISTÃO                 MONOMOTOR                 PARTICULAR
# 1          TURBOÉLICE                   BIMOTOR                 PARTICULAR
# 2          TURBOÉLICE                   BIMOTOR                    REGULAR
# 3                JATO                   BIMOTOR                    REGULAR
# 4                JATO                   BIMOTOR                    REGULAR
#
# ...

# %%
data.tail(n=5)
# Out:
#       codigo_ocorrencia aeronave_tipo_veiculo          aeronave_fabricante  \
# 6183              80249                 AVIÃO               BOEING COMPANY
# 6184              80251                 AVIÃO               BOEING COMPANY
# 6185              80257           HELICÓPTERO          ROBINSON HELICOPTER
# 6186              80258                 AVIÃO  NEIVA INDUSTRIA AERONAUTICA
# 6187              80259                 AVIÃO             AIRBUS INDUSTRIE
#
#      aeronave_motor_tipo aeronave_motor_quantidade aeronave_registro_segmento  \
# 6183                JATO                   BIMOTOR                    REGULAR
# 6184                JATO                   BIMOTOR                    REGULAR
# 6185              PISTÃO                 MONOMOTOR                 PARTICULAR
# 6186              PISTÃO                 MONOMOTOR                 PARTICULAR
# 6187                JATO                   BIMOTOR                    REGULAR
#
# ...

# %% [markdown]
# ### Dataset importado e checado quanto aos valores nulos se há ainda algum valor para ser observado.

# %%
### Check do dataset salvo, chamando a função criada anteriromente, para indenficar valores nulos, aqui nessa fase, eles não poderão existir.

# Código para checar valores nulos na base ocorrencia

total = data.isnull().sum().sort_values(ascending=False)
percent = data.isnull().sum()/data.isnull().count().sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, sort=False, keys=['Total', 'Percentil'])
missing_data[missing_data['Percentil']!=0]

missing_data.head(n=22)
# Out:
#                                 Total  Percentil
# codigo_ocorrencia                   0      0.00%
# latitude                            0      0.00%
# ocorrencia_periodos                 0      0.00%
# ocorrencia_ano                      0      0.00%
# ocorrencia_saida_pista              0      0.00%
# oc_aeronaves_envolvidas             0      0.00%
# ocorrencia_pais                     0      0.00%
# uf                                  0      0.00%
# ocorrencia_cidade                   0      0.00%
# longitude                           0      0.00%
# ocorrencia_classificacao            0      0.00%
# aeronave_tipo_veiculo               0      0.00%
# aeronave_peso_maximo_decolagem      0      0.00%
# aeronave_fatalidades_total          0      0.00%
# aeronave_nivel_dano                 0      0.00%
# aeronave_fase_operacao              0      0.00%
# aeronave_registro_segmento          0      0.00%
# aeronave_motor_quantidade           0      0.00%
# ...

# %% [markdown]
# ### Farei uma análise um pouco mais concentrada em Santa e Bela Catarina.

# %%
### Fazendo uma análise dos dados das ocorrências no estado de Santa Catarina com reset do index para o quantitativo de 10 posições

santa_catarina=data.loc[data.uf == 'SC', :]
santa_catarina.head(n=10).iloc[ :, 10: ].reset_index()
# Out:
#    index ocorrencia_classificacao        latitude       longitude  \
# 0     10                 ACIDENTE  -27.1919444444  -49.8313888889
# 1     26                INCIDENTE               0               0
# 2     27          INCIDENTE GRAVE  -26.2563888889  -50.9963888889
# 3     61                INCIDENTE               0               0
# 4     85                INCIDENTE               0               0
# 5     88                INCIDENTE               0               0
# 6    100                INCIDENTE               0               0
# 7    205                INCIDENTE               0               0
# 8    223                INCIDENTE               0               0
# 9    259                INCIDENTE               0               0
#
#   ocorrencia_cidade  uf ocorrencia_pais  oc_aeronaves_envolvidas  \
# 0      RIO DO OESTE  SC          BRASIL                        1
# 1     FLORIANÓPOLIS  SC          BRASIL                        1
# ...

# %%
# Agrupamento SC - quantitativo por tipo de veiculo e período das ocorrências e classificação

ocorrencia_tip= santa_catarina[['ocorrencia_periodos', 'ocorrencia_classificacao', 'ocorrencia_tipo']].groupby(
                               ['ocorrencia_periodos', 'ocorrencia_classificacao', 'ocorrencia_tipo']).size().reset_index()
ocorrencia_tip.head(n=15)
# Out:
#    ocorrencia_periodos ocorrencia_classificacao  \
# 0            MADRUGADA                INCIDENTE
# 1            MADRUGADA                INCIDENTE
# 2            MADRUGADA                INCIDENTE
# 3            MADRUGADA                INCIDENTE
# 4            MADRUGADA                INCIDENTE
# 5            MADRUGADA                INCIDENTE
# 6                MANHA                 ACIDENTE
# 7                MANHA                 ACIDENTE
# 8                MANHA                 ACIDENTE
# 9                MANHA                 ACIDENTE
# 10               MANHA                 ACIDENTE
# 11               MANHA                 ACIDENTE
# 12               MANHA                 ACIDENTE
# 13               MANHA                 ACIDENTE
# 14               MANHA                INCIDENTE
#
#                                       ocorrencia_tipo  0
# 0                                     COLISÃO COM AVE  1
# 1                                     ESTOURO DE PNEU  2
# ...

# %%
# Agrupamento SC - quantitativo por tipo de veiculo e período das ocorrências 

filtro_sc = santa_catarina[['ocorrencia_periodos', 'ocorrencia_classificacao', 'aeronave_tipo_veiculo']].groupby(
               ['ocorrencia_periodos', 'ocorrencia_classificacao', 'aeronave_tipo_veiculo']).count().reset_index()
filtro_sc.head(n=25)
# Out:
#    ocorrencia_periodos ocorrencia_classificacao aeronave_tipo_veiculo
# 0            MADRUGADA                INCIDENTE                 AVIÃO
# 1                MANHA                 ACIDENTE                 AVIÃO
# 2                MANHA                 ACIDENTE                 TRIKE
# 3                MANHA                INCIDENTE                 AVIÃO
# 4                MANHA                INCIDENTE           HELICÓPTERO
# 5                MANHA          INCIDENTE GRAVE                 AVIÃO
# 6                NOITE                 ACIDENTE                   ***
# 7                NOITE                 ACIDENTE                 AVIÃO
# 8                NOITE                 ACIDENTE           HELICÓPTERO
# 9                NOITE                 ACIDENTE             ULTRALEVE
# 10               NOITE                INCIDENTE                 AVIÃO
# 11               NOITE                INCIDENTE           HELICÓPTERO
# ...

# %% [markdown]
# ___
# ### Criação de uma função para plotagens dos gráficos e cenarizações.
#   - Para cada plot, gráfico criado, chamo essa function def para tratar dos detalhamentos dos plots
#    - Parâmetros plt %matplotlib para as labels
#    - Bar: gráficos verticais
#    - Barh: gráficos horizontais
# ___

# %%
### Function 
'''
  Dbian Data Scientist 
  Função responsável por anotar os indicadores das barras no gráfico.
  Entrada: tipo do gráfico ('bar' ou 'barh')
'''
def autolabel(tipo):
  if tipo == 'bar':
    for bar in plot.patches:
      plot.annotate(format(bar.get_height()),
                xy = (bar.get_x() + bar.get_width() / 2, bar.get_height()),
                xytext=(0, 8),
                textcoords='offset points',
                ha='center', 
                va='center',
                size=11)
  elif tipo == 'barh':
    for bar in plot.patches:
      plot.annotate(format(bar.get_width()),
                  xy = (bar.get_width() + 0.3, bar.get_y() + 0.38),
                  xytext=(15, -2),
                  textcoords='offset points',
                  ha='center', 
                  va='center',
                  size=11)

# %%
santa_catarina.head(3)
# Out:
#     codigo_ocorrencia aeronave_tipo_veiculo          aeronave_fabricante  \
# 10              39316                 AVIÃO                   AERO BOERO
# 26              39627                 AVIÃO             AIRBUS INDUSTRIE
# 27              39687                 AVIÃO  NEIVA INDUSTRIA AERONAUTICA
#
#    aeronave_motor_tipo aeronave_motor_quantidade aeronave_registro_segmento  \
# 10              PISTÃO                 MONOMOTOR                  INSTRUÇÃO
# 26                JATO                   BIMOTOR                    REGULAR
# 27              PISTÃO                 MONOMOTOR              ESPECIALIZADA
#
#    aeronave_fase_operacao aeronave_nivel_dano  aeronave_fatalidades_total  \
# 10                  POUSO         SUBSTANCIAL                           0
# 26                   TÁXI                LEVE                           0
# 27          ESPECIALIZADA              NENHUM                           0
#
# ...

# %%
# Plot do estado de SC

sc = santa_catarina[['ocorrencia_ano','ocorrencia_tipo']].groupby(['ocorrencia_ano'], 
                      as_index = True).count().sort_values(by='ocorrencia_tipo',ascending=False).tail(20)

plot = sc.plot(kind='bar', 
          color = ['#679436' ], figsize=(20, 7))
autolabel('bar') 

plot.set_title('OCORRÊNCIAS NO ESTADO DE SANTA CATARINA\n Quantitativo dás ocorrências por ano de fato ocorrido',
                                                                            pad=25, fontsize=13, color='#162521')
plot.set_xlabel('QTDE. OCORRÊNCIA ANO',
             fontsize=13, color='#162521')
plot.set_ylabel('ESCALA DO EIXO', 
             fontsize=13, color='#162521')
plot.tick_params('x', labelrotation=0)

plt.tight_layout()

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 7), sharey=True)

dados_tipo_aeronave = data.groupby('aeronave_tipo_veiculo')['aeronave_tipo_veiculo'].count()

tam_base = len(data)

plot = dados_tipo_aeronave.sort_values(ascending=False).plot(ax=axes[0],kind='bar',  
              color = ['#FFB703','#283618','#00B4D8', '#48CAE4' ], figsize=(20, 7))

autolabel('bar')
axes[0].set_title(f'AERONAVES EM OCORRÊNCIA POR TIPO DE AERONAVE\n(Conjunto de {tam_base} aeronaves)',
                                                                 pad=25, fontsize=15, color='#162521')
axes[0].set_xlabel('TIPO DE AERONAVE',
                fontsize=13, color='#162521')
axes[0].set_ylabel('QUANTIDADE DE AERONAVES',
                fontsize=13, color='#162521')
axes[0].tick_params('x', labelrotation=45)

plt.tight_layout()
 
dados_tipo_motor = data.groupby('aeronave_motor_tipo')['aeronave_motor_tipo'].count()

tam_base = len(data)

plot = dados_tipo_motor.sort_values(ascending=False).plot(ax=axes[1],kind='bar', 
            color = ['#FFB703','#283618','#00B4D8', '#48CAE4' ], figsize=(20, 7))
autolabel('bar')
axes[1].set_title(f'AERONAVES EM OCORRÊNCIA POR TIPO DE MOTOR\n(Conjunto de {tam_base} aeronaves)', 
                                                              pad=25, fontsize=15, color='#162521')
axes[1].set_xlabel('TIPO DE MOTOR', 
                fontsize=13, color='#162521')
axes[1].set_ylabel('QUANTIDADE DE AERONAVES', 
                fontsize=13, color='#162521')
axes[1].tick_params('x', labelrotation=45)
     
plt.tight_layout()

# %%
dados_fabricante_aeronave = data.groupby('aeronave_fabricante')['aeronave_fabricante'].count().sort_values()

plot = dados_fabricante_aeronave.tail(20).plot(kind='barh', 
                      color = ['#FFB703' ], figsize=(20, 7))
autolabel('barh')
plot.set_title('AERONAVES EM OCORRÊNCIA POR FABRICANTE\n Os 20 fabricantes com mais aeronaves envolvidas em ocorrências',
                                                                                    pad=25, fontsize=13, color='#162521')
plot.set_xlabel('QUANTIDADE DE AERONAVES',
             fontsize=13, color='#162521')
plot.set_ylabel('FABRICANTE', 
             fontsize=13, color='#162521')
plot.tick_params('x', labelrotation=0)

plt.tight_layout()

# %%
dados_fase_operacao = data.groupby('aeronave_fase_operacao')\
                                  ['aeronave_fase_operacao'].count()
tamanho_conjunto = len(data)

plot = dados_fase_operacao.sort_values().plot(kind='barh',
                    color = ['#283618' ],figsize=(20, 7))
autolabel('barh')
plot.set_title(f'AERONAVES EM OCORRÊNCIAS POR FASE DE OPERAÇÃO\n' +
                     f'(Conjunto de {tamanho_conjunto} aeronaves)', 
                              pad=25, fontsize=13, color='#162521')
plot.set_xlabel('FASE DE OPERAÇÂO',
               fontsize=13, color='#162521')
plot.set_ylabel('QUANTIDADE DE AERONAVES', 
               fontsize=13, color='#162521')
plot.tick_params('x', labelrotation=0)

plt.tight_layout()

# %%
fig, axes = plt.subplots(1, 2, figsize=(22, 7), sharey=False)

dados_quantidade_motor = data.groupby('aeronave_motor_quantidade')['aeronave_motor_quantidade'].count()

plot = dados_quantidade_motor.sort_values(ascending=False).plot(ax=axes[0],kind='bar',
                                                color = ['#FFB703' ], figsize=(20, 7))
autolabel('bar')
axes[0].set_title('AERONAVES EM OCORRÊNCIA POR QUANTIDADE DE MOTORES DA AERONAVE', 
                                             pad=25, fontsize=13, color='#162521')
axes[0].set_xlabel('QUANTIDADE DE MOTORES DA AERONAVE', 
                          fontsize=13, color='#162521') 
axes[0].set_ylabel('QUANTIDADE DE AERONAVES', 
                          fontsize=13, color='#162521')
axes[0].tick_params('x', labelrotation=45)

plt.tight_layout() 

dados_registro_segmento = data.groupby('aeronave_registro_segmento')\
                               ['aeronave_registro_segmento'].count()

plot = dados_registro_segmento.sort_values(ascending=False).plot(ax=axes[1],kind='bar',
                                                 color = ['#283618' ], figsize=(20, 7))
autolabel('bar')
axes[1].set_title('AERONAVES EM OCORRÊNCIA POR SEGMENTO',
                     pad=25,fontsize=13, color='#162521')
axes[1].set_xlabel('SEGMENTO', 
                            fontsize=13, color='#162521')
axes[1].set_ylabel('QUANTIDADE DE AERONAVES', 
                            fontsize=13, color='#162521')
axes[1].tick_params('x', labelrotation=45)

plt.tight_layout()

# %%
fig, axes = plt.subplots(1, 2, figsize=(22, 7), sharey=False)

dados_nivel_dano = data.groupby('aeronave_nivel_dano')['aeronave_nivel_dano'].count()

plot = dados_nivel_dano.sort_values(ascending=False).plot(ax=axes[0], kind='bar',
                                           color = ['#FFB703' ], figsize=(20, 7))
autolabel('bar')
axes[0].set_title('AERONAVES EM OCORRÊNCIA POR NÌVEL DE DANO NA AERONAVE',
                                     pad=25, fontsize=13, color='#162521')
axes[0].set_xlabel('NÌVEL DE DANO NA AERONAVE', 
                  fontsize=13, color='#162521')
axes[0].set_ylabel('QUANTIDADE DE AERONAVES',
                  fontsize=13, color='#162521')
axes[0].tick_params('x', labelrotation=45)

plt.tight_layout() 
selecao = data[data['aeronave_fatalidades_total'] > 0]
dados_fatalidade = selecao.groupby('aeronave_fatalidades_total')['aeronave_fatalidades_total'].count()

plot = dados_fatalidade.plot(ax=axes[1], kind='bar',
              color = ['#283618' ], figsize=(20, 7))
autolabel('bar')
axes[1].set_title('AERONAVES EM OCORRÊNCIA POR QUANTIDADE DE FATALIDADES',
                                     pad=25, fontsize=13, color='#162521')
axes[1].set_xlabel('QUANTIDADE DE FATALIDADES',
                  fontsize=13, color='#162521')
axes[1].set_ylabel('QUANTIDADE DE AERONAVES',
                fontsize=13, color='#162521')
axes[1].tick_params('x', labelrotation=45)

plt.tight_layout()

# %%
fig, axes = plt.subplots(1, 2, figsize=(22, 7), sharey=False)

# colors = sns.color_palette('deep')[0:5]
activities = ['sleeping', 'exercise', 'studying', 'working']
colors = ["orange", "lightblue", "magenta", "yellow"]
explode = (0.1, 0.1, 0.1, 0,) # cada binário representa o sequencial das fatias de indicadores

dados_peso_maximo = data.groupby('aeronave_peso_maximo_decolagem')['aeronave_peso_maximo_decolagem'].count()

axes[0].pie(dados_peso_maximo, labels = dados_peso_maximo.index, 
            explode=explode, colors = colors, autopct="%.2f%%", 
            shadow=True, startangle=90, textprops={'fontsize': 14}) #"%.2f"
axes[0].set_title('PERCENTUAL DE AERONAVES POR PESO MÁXIMO',
                       pad=25, fontsize=13, color='#162521')
plt.tight_layout() 

dados_classificacao_ocorrencia = data.groupby('ocorrencia_classificacao')['ocorrencia_classificacao'].count().sort_values(ascending=False)

axes[1].pie(dados_classificacao_ocorrencia, labels=dados_classificacao_ocorrencia.index, 
            colors = colors, autopct="%.2f%%", 
            shadow=True, startangle=90, textprops={'fontsize': 14})
axes[1].set_title('PERCENTUAL DE AERONAVES POR CLASSIFICAÇÃO DA OCORRÊNCIA', 
                                       pad=25, fontsize=13, color='#162521') 
plt.tight_layout()

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 7), sharey=False)
 
dados_ano_ocorrencia = data.groupby('ocorrencia_ano')['ocorrencia_ano'].count()

axes[0].plot(dados_ano_ocorrencia.index, dados_ano_ocorrencia, 
    color= '#FF5400', linewidth=2, marker=".", markersize=20.0)
axes[0].set_title('AERONAVES EM OCORRÊNCIA POR ANO\nEntre 2010 e 2021',
                                  pad=25, fontsize=13, color='#162521')
axes[0].set_xlabel('ANO', 
                   fontsize=13, color='#162521')
axes[0].set_ylabel('QUANTIDADE DE AERONAVES',
                   fontsize=13, color='#162521')
axes[0].set_ylim(300, 700)
axes[0].grid( linestyle='-', linewidth=1) 

plt.tight_layout()

dados_periodo_ocorrencia = data.groupby('ocorrencia_periodos')['ocorrencia_periodos'].count()

plot = dados_periodo_ocorrencia.sort_values(ascending=False).plot(ax=axes[1],kind='bar',
                                                  color = ['#283618' ], figsize=(20, 7))
autolabel('bar')
axes[1].tick_params('x', labelrotation=45)
axes[1].set_title('AERONAVES EM OCORRÊNCIA POR PERÍODO DO DIA',
                          pad=25, fontsize=13, color='#162521')
axes[1].set_xlabel('PERÌODO DO DIA', 
                                  fontsize=13, color='#162521')
axes[1].set_ylabel('QUANTIDADE DE AERONAVES', 
                                 fontsize=13, color='#162521');
plt.tight_layout()

# %%
dados_tipo_ocorrencia = data.groupby('ocorrencia_tipo')['ocorrencia_tipo'].count().sort_values()#.tail(20)

plot = dados_tipo_ocorrencia.tail(20).plot(kind='barh', 
                  color = ['#FFB703'], figsize=(20, 7))
autolabel('barh')
plot.set_title('QUANTIDADE DE OCORRÊNCIAS POR TIPO DE OCORRÊNCIA \n'+ 
                  'Os 20 tipos de ocorrências mais aeronaves envolvidas no período', 
                                                pad=25, fontsize=15, color='#162521')
plot.set_xlabel('QUANTIDADE DE AERONAVES', 
             fontsize=13, color='#162521')
plot.set_ylabel('TIPOS DE OCORRÊNCIA', 
             fontsize=13, color='#162521')
plot.tick_params('x', labelrotation=45)

plt.tight_layout()

# %%
fig, axes = plt.subplots(1, 2, figsize=(22, 7), sharey=False)

dados_aeronaves_envolvidas = data.groupby('oc_aeronaves_envolvidas')['oc_aeronaves_envolvidas'].count()

plot = dados_aeronaves_envolvidas.sort_values(ascending=False).plot(ax=axes[0],kind='bar', 
                                                                          color='#00B4D8')
autolabel('bar')
axes[0].tick_params('x', labelrotation=0)
axes[0].set_title('AERONAVES EM OCORRÊNCIA POR NÚMERO DE AERONAVES ENVOLVIDAS', 
                                          pad=25, fontsize=13, color='#162521')
axes[0].set_xlabel('NÚMERO DE AERONAVES ENVOLVIDAS', 
                       fontsize=13, color='#162521')
axes[0].set_ylabel('QUANTIDADE DE AERONAVES', 
                 fontsize=13, color='#162521') 

plt.tight_layout() 

# colors = sns.color_palette('deep')[0:5]
activities = ['sleeping', 'exercise', 'studying', 'working']
colors = ["orange", "lightblue", "magenta", "yellow"]
#explode = (0.1, 0, 0, 0) # cada binário representa o sequencial das fatias de indicadores
dados_saida_pista = data.groupby('ocorrencia_saida_pista')['ocorrencia_saida_pista'].count()

axes[1].pie(dados_saida_pista, labels=dados_saida_pista.index, 
            colors = colors, autopct='%.2f%%', textprops={'fontsize': 14})
axes[1].set_title('PERCENTUAL DE AERONAVES POR INDICADOR DE SAÍDA DE PISTA', 
                                       pad=25, fontsize=13, color='#162521')
plt.tight_layout()

# %%
dados_uf_ocorrencia = data.groupby('uf')['uf'].count()

plot = dados_uf_ocorrencia.sort_values(ascending=False).plot(kind='bar', 
   color = ['#FFB703','#283618','#00B4D8', '#48CAE4' ], figsize=(20, 7))
autolabel('bar')
plot.set_title('QUANTIDADE DE OCORRÊNCIAS POR UNIDADE FEDERATIVA',
                             pad=25, fontsize=13, color='#162521') 
plot.set_xlabel('UNIDADE FEDERATIVA', 
               fontsize=13, color='#162521') 
plot.set_ylabel('QUANTIDADE DE OCORRÊNCIAS',
               fontsize=13, color='#162521') 
plot.tick_params('x', labelrotation=45)
plt.tight_layout()

# %%
# Grafico agrupado por ocorrências das federações 

# round((data.groupby('ocorrencia_uf')['ocorrencia_uf'].count()/6188) * 100,ndigits=2)
plot_data = round((data.groupby('uf')['uf'].count()/6188) * 100,2)

plot = plot_data.sort_values(ascending=False).plot(kind='bar', 
color = ['#FFB703','#283618','#00B4D8', '#48CAE4' ], figsize=(20, 7))
autolabel('bar')
plot.set_title( 'QUANTIDADE DE OCORRÊNCIAS POR UNIDADE FEDERATIVA \n\n'+  
                'Percentil das ocorrências por federação', 
                                   pad=25, fontsize=13, color='#162521' )
                
plot.set_xlabel('UNIDADE FEDERATIVA', 
        fontsize=10, color='#162521')
plot.set_ylabel('QUANTIDADE DE OCORRÊNCIAS', 
        fontsize=12, color='#162521')
plot.tick_params('x', color='#162521',labelrotation=0)
plt.tight_layout()

# %% [markdown]
# ### Atributos cruzados e aplicação de EDA
#    - Farei o cruzamento de alguns atributos para entender o comportamento dos dados

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 7), sharey=False)

dados_fatalidades_tipo = data.groupby('aeronave_tipo_veiculo')['aeronave_fatalidades_total'].sum()

plot = dados_fatalidades_tipo.sort_values(ascending=False).plot(ax=axes[0],kind='bar',
                            color = ['#FFB703','#023E8A','#283618', '#48CAE4' ], figsize=(20, 7))
autolabel('bar')
axes[0].tick_params('x', labelrotation=45)
axes[0].set_title('NÚMERO DE FATALIDADES POR TIPO DE AERONAVE', 
                                                pad=25, fontsize=12, color='#162521')
axes[0].set_xlabel('TIPO DE AERONAVE', 
                                                        fontsize=12, color='#162521')
axes[0].set_ylabel('NÚMERO DE FATALIDADES', 
                                                        fontsize=12, color='#162521')

plt.tight_layout() 

dados_fatalidades_nivel = data.groupby('aeronave_nivel_dano')['aeronave_fatalidades_total'].sum()


plot = dados_fatalidades_nivel.sort_values(ascending=False).plot(ax=axes[1], kind='bar',
                            color = ['#FFB703','#023E8A','#283618', '#48CAE4' ], figsize=(20, 7))
autolabel('bar')
axes[1].tick_params('x', labelrotation=0)
axes[1].set_title('NÚMERO DE FATALIDADES POR TIPO DE DANOS NA AERONAVE', 
                                                pad=25, fontsize=12, color='#162521')
axes[1].set_xlabel('NÍVEL DO DANO', 
                                                        fontsize=12, color='#162521')
axes[1].set_ylabel('NÚMERO DE FATALIDADES', 
                                                       fontsize=12, color='#162521');
plt.tight_layout()

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 7), sharey=False)

dados_fatalidades_ano = data.groupby('ocorrencia_ano')['aeronave_fatalidades_total'].sum()

axes[0].plot(dados_fatalidades_ano.index, dados_fatalidades_ano, color= '#FF5400', linewidth=2, marker=".", markersize=20.0),
                                                                    
axes[0].set_title('NÚMERO DE FATALIDADES POR ANO',
                         pad=25,  fontsize=14, color='#162521')
axes[0].set_xlabel('ANO', 
                   fontsize=12, color='#162521')
axes[0].set_ylabel('NÚMERO DE FATALIDADES', 
                   fontsize=12, color='#162521')
axes[0].set_ylim(0, 150)
axes[0].grid( linestyle='-', linewidth=1)
plt.tight_layout()

dados_fatalidades_nivel = data.groupby('oc_aeronaves_envolvidas')['aeronave_fatalidades_total'].sum()

plot = dados_fatalidades_nivel.sort_values(ascending=False).plot(ax=axes[1], kind='bar',
                                                   color = ['#283618'], figsize=(20, 7))
autolabel('bar')
axes[1].tick_params('x', labelrotation=0)
axes[1].set_title('NÚMERO DE FATALIDADES POR NÚMERO DE AERONAVES ENVOLVIDAS', 
                                                    pad=25,  fontsize=14, color='#162521')
axes[1].set_xlabel('NÚMERO DE AERONAVES ENVOLVIDAS', 
                   fontsize=12, color='#162521')
axes[1].set_ylabel('NÚMERO DE FATALIDADES', 
                   fontsize=12, color='#162521');
plt.tight_layout()

# %%
dados_fatalidades_ano

plot = dados_fatalidades_ano.sort_values(ascending=False).plot(kind='bar',color = 
                    ['#FFB703','#EF233C','#283618', '#48CAE4' ], figsize=(20, 7))
autolabel('bar')
plot.set_title( 'QUANTITATIVO DAS OCORRÊNCIAS POR FATALIDADE \n\n'+  
               'Quantidade das Fatalidades por ano', pad=25, 
                              fontsize=15, color='#00296B' )
                
plot.set_xlabel('UNIDADE FEDERATIVA', 
        fontsize=10, color='#00296B')
plot.set_ylabel('QUANTIDADE DE OCORRÊNCIAS',
               fontsize=10, color='#00296B')
plot.tick_params('x', color='#00296B',labelrotation=0)
plt.tight_layout()

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 7), sharey=False)

selecao = data.query("aeronave_tipo_veiculo in ['AVIÃO','HELICÓPTERO','ULTRALEVE']")

plot = sns.countplot(ax=axes[0], x='aeronave_tipo_veiculo',data=selecao, palette='muted',hue='ocorrencia_classificacao')
axes[0].tick_params('x', labelrotation=0)
axes[0].set_title('AERONAVES EM OCORRÊNCIA POR TIPOS DE AERONAVE\n'+
                  'E CLASSIFICAÇÃO DE OCORRÊNCIAS\n'+
                  '(Filtro: Avião, Helicóptero, Ultraleve)', 
                           pad=25, fontsize=13, color='#162521')
axes[0].set_xlabel('TIPO DE AERONAVE',
         fontsize=13, color='#162521')
axes[0].set_ylabel('QUANTIDADE DE AERONAVES', 
                fontsize=13, color='#162521')
plt.tight_layout()
for p in plot.patches:
  plot.annotate(format(p.get_height()), 
                xy = (p.get_x()+0.15, p.get_height()),
                xytext=(0, 8),
                textcoords='offset points',
                ha='center', 
                va='center',
                size=11)

selecao = data.query("aeronave_nivel_dano in ['DESTRUÍDA','SUBSTANCIAL','LEVE','NENHUM']")

plot = sns.countplot(ax=axes[1],x='aeronave_nivel_dano',data=selecao, palette='muted',hue='ocorrencia_classificacao')
axes[1].tick_params('x', labelrotation=0)
axes[1].set_title('AERONAVES EM OCORRÊNCIA POR NIVEL DE DANO DA AERONAVE\n'+
                  'E CLASSIFICAÇÃO DE OCORRÊNCIAS\n', 
                pad= 25, fontsize=13, color='#162521')
axes[1].set_xlabel('NIVEL DE DANO', 
      fontsize=13, color='#162521')
axes[1].set_ylabel('QUANTIDADE DE AERONAVES', 
                fontsize=13, color='#162521')

for p in plot.patches:
  plot.annotate(format(p.get_height()), 
                xy = (p.get_x()+0.15, p.get_height()),
                xytext=(0, 8),
                textcoords='offset points',
                ha='center', 
                va='center',
                size=11)
plt.tight_layout()

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 7), sharey=False)

selecao = data.query("aeronave_motor_quantidade in ['BIMOTOR','MONOMOTOR']")

plot = sns.countplot(ax=axes[0],x='aeronave_motor_quantidade',data=selecao, palette='muted',hue='ocorrencia_classificacao')
axes[0].tick_params('x', labelrotation=0)
axes[0].set_title('AERONAVES EM OCORRÊNCIA POR QUANTIDADE DE MOTORES\n'+
                  'E CLASSIFICAÇÃO DE OCORRÊNCIAS\n'+
                  '(Filtro: Monomotor, Bimotor)', 
                    fontsize=13, color='#162521')
axes[0].set_xlabel('QUANTIDADE DE MOTORES', 
              fontsize=13, color='#162521')
axes[0].set_ylabel('QUANTIDADE DE AERONAVES', 
                fontsize=13, color='#162521')
plt.tight_layout()

for p in plot.patches:
  plot.annotate(format(p.get_height()), 
                xy = (p.get_x()+0.15, p.get_height()),
                xytext=(0, 8),
                textcoords='offset points',
                ha='center', 
                va='center',
                size=11)

selecao = data.query("aeronave_peso_maximo_decolagem in ['Faixa ate 2250KG','Faixa de 5700KG','Acima de 2250KG e 5700KG']")

plot = sns.countplot(ax=axes[1],x='aeronave_peso_maximo_decolagem',data=selecao, palette='muted',hue='ocorrencia_classificacao')
axes[1].tick_params('x', labelrotation=0)
axes[1].set_title('AERONAVES EM OCORRÊNCIA POR PESO MÁXIMO\n'+
                                        'E CLASSIFICAÇÃO DE OCORRÊNCIAS\n', 
                                              fontsize=13, color='#162521')
axes[1].set_xlabel('PESO MÁXIMO',
    fontsize=13, color='#162521')
axes[1].set_ylabel('QUANTIDADE DE AERONAVES', 
                fontsize=13, color='#162521')

for p in plot.patches:
  plot.annotate(format(p.get_height()), 
                xy = (p.get_x()+0.15, p.get_height()),
                xytext=(0, 8),
                textcoords='offset points',
                ha='center', 
                va='center',
                size=11)
plt.tight_layout()

# %%
selecao = data[data['uf'] == 'SP']
dados_tipo_ocorrencia = selecao.groupby('ocorrencia_tipo')['ocorrencia_tipo'].count().sort_values().tail(10)

plot = dados_tipo_ocorrencia.tail(20).plot(kind='barh',color = 
                                 ['#FFB703' ], figsize=(20, 7))
autolabel('barh')
plot.set_title('QUANTIDADE DE OCORRÊNCIAS POR TIPO DE OCORRÊNCIA \n'+ 
                  '10 Tipos de Ocorrência Mais Frequentes no Estado de São Paulo', 
                                            pad=25, fontsize=15, color='#162521')
plot.set_xlabel('QUANTIDADE DE AERONAVES', 
             fontsize=13, color='#162521')
plot.set_ylabel('TIPOS DE OCORRÊNCIA', 
             fontsize=13, color='#162521')
plot.tick_params('x', labelrotation=0) 
plt.tight_layout()

# %% [markdown]
# ___
# ### Considerações:
#
#   - Através da metodologia CRISP-DM determinaram-se os passos para elaboração de um projeto de análise de dados:
#     - Entendimento do Negócio;
#     - Entendimento dos Dados;
#     - Preparação dos Dados;
#     - Modelagem, Avaliação e Implementação de conceitos.
#     - Todos os passos foram baseados na perspectiva de negócio e executados de forma cíclica, garantindo assim a melhoria contínua, como prevê a própria metodologia.
#
#       - O trabalho como já éra previsto, foi muito produtivo e gerou muita informação relevante, são informações que ao longo de todo o processo, voram sendo geradas e validadas atraés dos coneitos propostos, com análise e gerenciameto dos dados, para que fosse possível empregar técnicas de mineração e modelagem, para que então pudessem serem consumidas.
# ___

# %%
print( 
      '\nDBIAN TECHNOLOGY\n',
      '\nClaudio Fabian Stychnicki',
      '\nPhone/Whats: (47) 99237-4737',
      '\nBlumenau - SC\n',
      '\nInformações complementares em meu linkedIn\n',
      '\nThanks so musch!'
      )
# Out:
# DBIAN TECHNOLOGY
#
# Claudio Fabian Stychnicki
# Phone/Whats: (47) 99237-4737
# Blumenau - SC
#
# Informações complementares em meu linkedIn
#
# Thanks so musch!

# %% [markdown]
# ___
# ### Processo final, será o deploy do @App_Cenipa!

# %% [markdown]
# ___
